# %% [markdown]
# # **12주차 과제**

# %% [markdown]
# **안내사항**
# - 셀 출력 결과물은 이미지로 첨부하였습니다.
# - Colab에서 확인할 시에 마크다운 셀의 출력 이미지가 안보일 수 있습니다.
# - 데이터프레임에서 컬럼 순서, 컬럼 이름은 항상 정확하게 반영해주시길 바랍니다.
# - 별도의 조건이 없다면, 데이터 정렬에서 인덱스 번호는 따로 신경쓰지 않으셔도 괜찮습니다.
# ※ 명시된 조건들은 반드시 준수하시길 바랍니다.

# %% [markdown]
# **확인사항**
# - 함수, 클래스 문제에서는 입력인자를 꼼꼼하게 확인해주시길 바랍니다.
# - print, display 함수도 꼼꼼하게 확인하여 출력 결과를 만들어주시길 바랍니다.
# - 데이터에 대한 정보 출력, print 사항도 꼼꼼하게 확인해주시길 바랍니다. 오답의 요인이 될 수 있습니다.

# %%
# 불필요한 출력을 없애기 위한 코드입니다.
# 문제풀이와는 무관합니다.
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Q1. 클래스 설계 - 네이버 뉴스 정보 크롤링**

# %% [markdown]
# ### **문제 설명**
# - Selenium, requests, BeautifulSoup 모두 활용 가능

# %% [markdown]
# ### **수집 대상 정보**

# %% [markdown]
# - **수집대상 정보입니다.**
#
# - 과제 제작 환경에서는 검색어가 입력되었을 때, 10개의 뉴스 정보가 나왔습니다.

# %% [markdown]
# <img src="./참고이미지/Q1_1.png">

# %% [markdown]
# <img src="./참고이미지/Q1_2.png">

# %% [markdown]
# > **뉴스탭 검색 결과의 기준 화면**
# >
# > - 네이버에서 뉴스탭에 검색어를 입력했을 때, **검색 직후의 화면(스크롤 없이 보이는 영역)** 을 기준으로 합니다.
# > - **해당 화면에 뉴스 기사 정보만 수집**하면 됩니다.
# > - 스크롤을 내리거나 추가적인 동작은 수행하지 않습니다.
# >
# > 아래 이미지에 표시된 뉴스 기사 영역만을 수집 대상으로 삼습니다.

# %% [markdown]
# <img src="./참고이미지/Q1_0.png">

# %% [markdown]
# > **화면의 태그 구성**
# > - 뉴스탭 HTML 구조를 보여주는 참고 이미지입니다.
# > - 과제에서는 **스크롤 전 기본 화면만 활용**하므로, 해당 이미지는 구조 참고용으로만 활용하세요.

# %% [markdown]
# <img src="./참고이미지/Q1_0_0.png">

# %% [markdown]
# - 아래 메서드를 구현합니다.

# %% [markdown]
# - **naver_news_search 메서드**
#     - 입력한 검색어로 네이버 뉴스탭에서 관련 기사 정보를 수집합니다.
#     - 기사 정보는 **제목, 링크, 언론사, 요약 내용**을 포함합니다.
#     - **제목과 언론사가 같은 뉴스는 중복으로 판단하고 제거**합니다.
#     - 수집한 뉴스 목록은 **self.result_df 변수에 데이터프레임 형태로 저장**합니다.
#     - 기사 수를 기준으로 **많이 등장한 상위 5개 언론사 목록을 self.press_top5에 저장**합니다.
#     - 문제 푸는 시점에 중복 데이터가 없었다면, 채점 과정에서는 코드 재실행 결과 확인 및 논리성을 검토할 예정입니다.

# %% [markdown]
# - **press_search 메서드**
#     - self.result_df에 저장된 뉴스 데이터를 기반으로 **언론사별 기사 비율(%)을 계산**합니다.
#     - 전체 기사 중에서 **각 언론사가 차지하는 비율을 반환**합니다.

# %%
class news_collector:
    def __init__(self):


    def naver_news_search(self, search_keyword_list):


    def press_search(self, press_col, press_list, keyword_col):
# Out:
#   Cell In[2], line 5
#     def naver_news_search(self, search_keyword_list):
#     ^
# IndentationError: expected an indented block

# %%
''' 해당 셀에 별도의 코드를 작성하여 결과를 도출할 경우 오답으로 처리됩니다. '''
''' 해당 셀에서 아무런 추가 작업 없이 동일한 결과가 나타나야 합니다.'''
news_class = news_collector()
news_class.naver_news_search(search_keyword_list=['게임', '영화', '음악', 'AI', '위메이드'])

# %%
''' 해당 셀에 별도의 코드를 작성하여 결과를 도출할 경우 오답으로 처리됩니다. '''
print('='*30, 'news_class.result_df.shape 확인결과', '='*30)
print(news_class.result_df.shape)

# %%
''' 해당 셀에 별도의 코드를 작성하여 결과를 도출할 경우 오답으로 처리됩니다. '''
print('='*30, 'news_class.result_df 확인결과', '='*30)
display(news_class.result_df) # 검색 결과 데이터프레임 => 데이터베이스 기반

# %% [markdown]
# <img src="./참고이미지/Q1_3.png">

# %% [markdown]
# <img src="./참고이미지/Q1_4.png">

# %%
''' 해당 셀에 별도의 코드를 작성하여 결과를 도출할 경우 오답으로 처리됩니다. '''
print('='*30, 'news_class.press_top5 확인결과', '='*30)
display(news_class.press_top5) # 언론사 갯수 top5

# %% [markdown]
# <img src="./참고이미지/Q1_5.png">

# %% [markdown]
# - **press_search 메서드 실행 결과**
#     - 언론사 목록(press_list)을 기준으로 **각 언론사별 뉴스 데이터를 차례로 확인**합니다.
#     - 각 언론사의 뉴스 기사에서 **입력한 검색어가 등장하는 비율을 계산하여 보여줍니다.**
#     - 언론사별로 **해당 키워드가 얼마나 자주 등장했는지**를 분석할 수 있습니다.

# %% [markdown]
# - **구현 조건**
#
# - `press_search` 메서드는 다음과 같은 매개변수를 받습니다:
#   - `press_col`: 언론사 정보가 들어 있는 컬럼명 (예: '언론사')
#   - `keyword_col`: 검색어가 저장된 컬럼명 (예: '검색어')
#   - `press_list`: 분석 대상이 될 언론사 리스트

# %%
# 해당 셀에 별도의 코드를 추가하거나 수정하여 결과를 도출할 경우, 오답 처리됩니다.  
# 파이 차트(pie chart)는 도넛 형태(donut chart)가 되도록 중앙에 구멍을 두는 옵션을 반드시 반영해야 함.  
# 구멍의 크기에 대한 별도의 조건은 없음

news_class.press_search(press_col='언론사', keyword_col = '검색어',
                        press_list=['연합뉴스', '뉴시스언론사 선정', '뉴스1'])

# %% [markdown]
# <img src="./참고이미지/Q1_6.png">

# %% [markdown]
# <img src="./참고이미지/Q1_7.png">

# %% [markdown]
# <img src="./참고이미지/Q1_8.png">

# %% [markdown]
# ## **Q2. 데이터 전처리 - Pandas**
# - 데이터프레임에서 데이터의 정렬 상태도 확인하시고 반영해주시길 바랍니다.

# %% [markdown]
# - 전처리

# %%
# 데이터 확인용 코드셀입니다. 정답과는 무관합니다.
import pandas as pd
df_orders = pd.read_csv('./data_thelook_ecommerce/orders.csv')
df_users = pd.read_csv('./data_thelook_ecommerce/users.csv')

print(f"{df_orders.shape}")
print(f"{df_orders.columns}")
print(f"{df_users.shape}")
print(f"{df_users.columns}")

# %% [markdown]
# - **전처리 1. 국가별 3회 이상 주문자 비율 확인**
#     - 주문 데이터(orders)에서 **status가 'Shipped'인 데이터만 분석 대상으로 사용**합니다.
#     - 사용자 정보(users.csv)의 `id` 컬럼을 user_id로 생각합니다.
#     - 각 국가별로 **'Shipped' 상태의 주문을 3회 이상 한 사용자 비율**을 계산합니다.

# %%
''' 코드를 작성해주세요 '''

# %% [markdown]
# <img src="./참고이미지/Q2_1.png">

# %% [markdown]
# <img src="./참고이미지/Q2_1_1.png">

# %% [markdown]
# - **전처리 2. 국가별 주문 횟수 비율을 확인합니다.**
# - orders에서 status는 Shipped인 데이터만 집계 대상으로 합니다.

# %%
''' 코드를 작성해주세요 '''

# %% [markdown]
# <img src="./참고이미지/Q2_2.png">

# %% [markdown]
# - **데이터 결합**
# - 위에서 작업한 두 데이터프레임을 결합합니다.

# %% [markdown]
# <img src="./참고이미지/Q2_3.png">

# %% [markdown]
# - **그래프에서 색상을 통일할 필요는 없습니다**
#     - 시각화의 핵심은 **비율 차이를 명확하게 표현**하는 것이며, 색상은 자유롭게 사용해도 됩니다.
#
# - **그래프에서의 자릿수는 기본 옵션으로 출력된 결과입니다**
#     - 별도의 포맷팅이나 스타일 설정 없이도 **기본 설정을 그대로 활용해도 무방**합니다.

# %%
# 위에서 만든 데이터프레임에 대한 시각화를 수행해주세요
# user_count에 대한 pie chart 시각화를 진행하여 user_ratio를 확인해주세요

# %% [markdown]
# <img src="./참고이미지/Q2_4.png">

# %%
# 위에서 만든 데이터프레임에 대한 시각화를 수행해주세요
# order_count에 대한 pie chart 시각화를 진행하여 order_ratio를 확인해주세요.

# %% [markdown]
# <img src="./참고이미지/Q2_5.png">

# %% [markdown]
# ## **Q3 ~ Q4. BigQuery**
# - Q2에서의 작업들을 BigQuery와 연결하여 수행하는 문제입니다.
# - BigQuery에서 로컬로 데이터를 다운받고 문제를 풀이 하는 것이 아닙니다.

# %% [markdown]
# ## **Q3. 데이터 전처리 - BigQuery 전처리 1**

# %% [markdown]
# - **동일한 결과를 나타내는 하나의 BigQuery 쿼리문을 작성하고 출력 결과를 나타내주세요**
#     - 하나의 쿼리로 모든 연산이 이루어지도록 작성해야 합니다.
#
# - **공공 데이터셋이므로, 출력 시점에 따라 데이터 출력이 일부 다를 수 있음은 채점 과정에서 반영하겠습니다**
#     - 데이터는 Google BigQuery의 **공공 데이터셋**에서 실시간으로 불러오기 때문에,
#     - **시점에 따라 일부 수치나 결과가 다를 수 있으며 이는 감안하여 평가합니다.**

# %%
from google.oauth2 import service_account
from google.cloud import bigquery

# %% [markdown]
# - **Query 1**

# %% [markdown]
# - bigquery-public-data.thelook_ecommerce 데이터셋을 활용합니다.
# - 공공데이터셋이므로, 출력 결과가 달라질 수 있음은 채점과정에서 고려할 것입니다.
# - 하나의 BigQuery 쿼리문을 통해 Q2와 동일한 출력 결과를 만들어 주세요

# %% [markdown]
# <img src="./참고이미지/Q3_1.png">

# %% [markdown]
# - **Query 2**

# %% [markdown]
# - bigquery-public-data.thelook_ecommerce 데이터셋을 활용합니다.
# - 공공데이터셋이므로, 출력 결과가 달라질 수 있음은 채점과정에서 고려할 것입니다.
# - 하나의 BigQuery 쿼리문을 통해 Q2와 동일한 출력 결과를 만들어 주세요

# %% [markdown]
# <img src="./참고이미지/Q3_2.png">

# %% [markdown]
# # **Q4 데이터 전처리 - BigQuery 전처리 2**

# %% [markdown]
# - **동일한 결과를 나타내는 하나의 BigQuery 쿼리문을 작성하고 출력 결과를 나타내주세요**
# - 공공 데이터셋이므로, 출력 시점에 따라 데이터 출력이 일부 다를 수 있음은 채점 과정에서 반영하겠습니다.

# %%
# bigquery-public-data.thelook_ecommerce 데이터셋을 활용합니다.
# 공공데이터셋이므로, 출력 결과가 달라질 수 있음은 채점과정에서 고려할 것입니다.
# 하나의 BigQuery 쿼리문을 통해 아래 결과를 나타내주세요

# %% [markdown]
# <img src="./참고이미지/Q4.png">

# %% [markdown]
# ## **🔎 [주관식 과제 수행 시 유의사항]**
#
# > **✅ 1. 정확한 출력값과 요구사항 이행 필수**
#
# 주관식 채점은 다음 기준에 따라 평가됩니다.
#
# 1)출력 결과의 정확성
# - 제공된 예시 결과와 동일한 출력이 나와야 합니다.
# - 단, 실시간 데이터나 인공지능 학습 등으로 출력값에 변동성이 존재할 수 있는 문제는 예외로 처리합니다.
#
# 2)문제 요구사항의 충실한 반영
# - 조건, 컬럼명, 출력 형식 등 모든 요구사항을 빠짐없이 반영해야 합니다.
# - 사소한 조건도 놓치지 않도록 세심하게 코드를 작성해 주세요.
#
#
# > **✅ 2. 완성된 코드 제출 필수**
#
# 가. 제출한 코드 셀은 채점 시 직접 실행하여 결과를 확인할 수 있습니다.
#
# - 재실행 시에도 동일한 결과가 나와야 정답으로 인정됩니다.
#
# 나. 버전 차이에 따른 미세한 수치 차이는 감안하나, 결과 형태나 구조가 다르면 감점 또는 오답 처리될 수 있습니다.
#
# 다. 시각화 문제에서 색상 지정이 없다면, 기본(default) 색상 사용을 전제로 합니다.
# - 환경에 따라 색상이 다르게 출력되더라도 불이익은 없습니다.
#
# > **✅ 3. 사용자 선언 함수/클래스 문제 주의사항**
#
# 사용자 정의 함수, 클래스, 메서드와 관련된 문제에서는 추가적인 코드 없이도 함수만으로 정답 결과가 도출되어야 합니다.
# - ❌ 함수 외부에서 plt.title, print, info() 등을 추가하여 결과를 보완하면 오답 처리됩니다.
#
# > **✅ 4. 함수/클래스 선언 시 일관된 결과 유지**
#
# 가. 함수, 클래스, 메서드는 반복 실행 시에도 항상 동일한 결과를 반환해야 합니다.
# 나. 채점 중 재실행 결과가 다르면 오답으로 처리됩니다.
#
# > **📌 [안내 정리]**
#
# 가. 문제의 모든 조건을 꼼꼼히 확인하고 반영해 주세요.
# 나. 과제는 실무와 유사한 기준으로 평가되며, 요구 조건을 충족하지 않을 경우 0점 처리될 수 있습니다.
