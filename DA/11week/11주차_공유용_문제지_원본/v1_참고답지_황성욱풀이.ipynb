# %% [markdown]
# # **11주차 과제**

# %% [markdown]
# **안내사항**
# - 셀 출력 결과물은 이미지로 첨부하였습니다.
# - Colab에서 확인할 시에 마크다운 셀의 출력 이미지가 안보일 수 있습니다.
# - 별도의 조건이 없다면, 데이터 정렬에서 인덱스 번호는 따로 신경쓰지 않으셔도 괜찮습니다.
# ※ 명시된 조건들은 반드시 준수하시길 바랍니다.

# %% [markdown]
# **확인사항**
# - 함수, 클래스 문제에서는 입력인자를 꼼꼼하게 확인해주시길 바랍니다.
# - print, display 함수도 꼼꼼하게 확인하여 출력 결과를 만들어주시길 바랍니다.
# - 데이터에 대한 정보 출력, print 사항도 꼼꼼하게 확인해주시길 바랍니다. 오답의 요인이 될 수 있습니다.

# %%
# 불필요한 출력을 없애기 위한 코드입니다.
# 문제풀이와는 무관합니다.
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Q1~Q3. **Python에서 Database 다루기**

# %% [markdown]
# ## Q1. 데이터베이스로부터 데이터 불러오기

# %% [markdown]
# - 데이터 정보 및 준수할 사항
#   - **데이터**: 직접 구성한 데이터베이스에 `pokemon` 테이블을 생성하고 데이터를 불러옵니다.
#   - **출력 결과와 동일하게**, 필요한 컬럼만 선택하여 불러옵니다.
#   - 테이블 생성 시에는 제공된 `.csv` 파일 또는 `.sql` 파일 중 **편리한 방법**을 사용하셔도 됩니다.
#   - Q1 문제에서는 **데이터베이스 생성, 테이블 생성, 데이터 삽입 과정은 Python 코드로 수행하지 않아도 됩니다.**
#
# - 쿼리로 반드시 진행해야 할 사항
#   - 전체 데이터를 불러온 후 Pandas에서 컬럼을 제거하는 방식이 아니라,
#   **SQL 쿼리 내에서 필요한 컬럼만 선택**하여 불러와야 합니다.
#     컬럼 이름, 컬럼 순서, 컬럼 갯수 모두 평가 요소입니다.
#
# - Pandas로 진행할 사항
#   - 쿼리 결과를 불러온 뒤, **Pandas의 DataFrame 정보 출력**을 수행합니다.

# %%
# mysql 연결을 진행해주세요

import mysql.connector

conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='1234',
    database='pokemon'
)

# %% [markdown]
# - 전처 데이터 중에서 아래에 해당하는 타입을 가진 데이터만 가져옵니다.
#     - 'GRASS', 'POISON', 'FIRE', 'FLYING', 'DRAGON'

# %%
# 원하는 데이터만 가져오기 위한 쿼리를 작성해주세요

import pandas as pd

query = """
SELECT NAME, Type
FROM pokemon_prep
WHERE Type = 'GRASS'
OR Type = 'POISON'
OR Type = 'FIRE'
OR Type = 'FLYING'
OR Type = 'DRAGON'
"""

tmp_df = pd.read_sql(query, conn)

display(tmp_df)
# Out:
#                  NAME    Type
# 0          Charmander    FIRE
# 1          Charmeleon    FIRE
# 2           Charizard    FIRE
# 3    Mega Charizard X    FIRE
# 4    Mega Charizard Y    FIRE
# ..                ...     ...
# 173        Chesnaught   GRASS
# 174            Skiddo   GRASS
# 175            Gogoat   GRASS
# 176            Skrelp  POISON
# 177          Dragalge  POISON
#
# [178 rows x 2 columns]

# %% [markdown]
# <img src="./참고이미지/Q1/result1.png">

# %% [markdown]
# ## Q2. 포켓몬 타입별 포켓몬 숫자 및 비율 확인

# %% [markdown]
# **MySQL은 사용하지 말고, Python과 Pandas를 활용하여 해당 집계를 수행합니다**

# %% [markdown]
# - 위 데이터에 대한 집계를 수행합니다.
# - type별로 포켓몬 숫자를 집계하여 확인합니다.
# - 컬럼 이름과, 데이터 정렬 순서도 채점 요소에 포함됩니다.
# - 비율의 경우, 자릿수도 확인해주시길 바랍니다.
# - 인덱스 정보는 초기화합니다.

# %%
# Q1 데이터 집계를 위한 코드를 작성해주세요

tmp_df = pd.read_csv(".\data\pokemon_prep.csv")
Types = ['GRASS', 'POISON', 'FIRE', 'FLYING', 'DRAGON']
tmp_df_types = tmp_df[tmp_df['Type'].isin(Types)][['Name','Type']]
tmp_df1 = tmp_df_types.groupby('Type')['Name'].count().sort_values(ascending=False).reset_index(name='Number_of_Pokemons')
display(tmp_df1.head())
# Out:
#      Type  Number_of_Pokemons
# 0   GRASS                  69
# 1    FIRE                  50
# 2  POISON                  28
# 3  DRAGON                  27
# 4  FLYING                   4

# %% [markdown]
# <img src="./참고이미지/Q2/Q2_result1.png">

# %%
# 해당 데이터에서 정보를 추가하기 위한 코드를 작성해주세요

tmp_df2 = tmp_df1.copy()
tmp_df2['ratio'] = (tmp_df2['Number_of_Pokemons'] * 100 / tmp_df2['Number_of_Pokemons'].sum()).round(1)
display(tmp_df2)
# Out:
#      Type  Number_of_Pokemons  ratio
# 0   GRASS                  69   38.8
# 1    FIRE                  50   28.1
# 2  POISON                  28   15.7
# 3  DRAGON                  27   15.2
# 4  FLYING                   4    2.2

# %% [markdown]
# <img src="./참고이미지/Q2/Q2_result2.png">

# %% [markdown]
# ## Q3. 타입별 포켓몬 숫자 시각화

# %% [markdown]
# ### ▷ 시각화 조건 및 유의사항
# - **색상은 자유롭게 설정**해도 되며, 별도의 지정된 색상은 없습니다.
# - **차트 제목은 정확하게 출력**해 주세요.
#
# ### ▷ 시각화 종류 및 목적
# - **Pie Chart**
#   - 타입별 포켓몬의 **비율**을 시각화합니다.
#
# - **Barplot Chart**
#   - 타입별 포켓몬의 **개수를 시각화**합니다.
#   - **배경 옵션 및 차트 제목** 설정을 포함하여 시각화를 마무리합니다.

# %%
# 데이터 시각화를 위한 코드를 작성해주세요

import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(2,1, figsize=(7,9))
ax[0].pie(tmp_df2['ratio'], autopct='%1.1f%%', startangle=90)
ax[0].set_title('Pokemon Type Ratio', loc='left', pad=20)
ax[0].legend(tmp_df2['Type'], loc='center left', bbox_to_anchor=(1, 0.5), frameon=False)

sns.barplot(tmp_df2, x='Type', y='Number_of_Pokemons', ax=ax[1])
ax[1].set_title('Pokemon Type Number')
ax[1].grid(True)
plt.show()

# %% [markdown]
# <img src="./참고이미지/Q3/Q3_result1.png" width="90%">

# %% [markdown]
# ## Q4. 함수 선언
#
# ### ▷ 데이터
# - Q1에서 불러온 데이터프레임을 기반으로 작업을 수행합니다.
#
# ### ▷ 함수 동작 요구사항
# - **특정 컬럼에서 특정 데이터를 삭제한 후**, 삭제 전후의 결과를 비교하여 **시각화**를 수행합니다.
# - 데이터 삭제는 **SQL 쿼리가 아닌 Python 코드**로만 진행해야 합니다.
# - 집계 데이터프레임에서는 **컬럼명과 정렬 순서**를 정확하게 유지해 주세요.
# - 시각화에 사용할 **색상은 자유롭게 선택**할 수 있으며, 별도의 색상 지정은 없습니다.

# %%
# 함수 선언 코드 작성 및 함수 실행을 수행해주세요

def prep_function(df, drop_col, drop_data):

    print('='*20,'삭제 작업 이전 상태입니다.', '='*20)
    Types = ['GRASS', 'POISON', 'FIRE', 'FLYING', 'DRAGON']
    tmp_df_types = df[df['Type'].isin(Types)][['Name','Type']]
    print(tmp_df_types.shape)
    tmp_df_data = tmp_df_types.groupby('Type')['Name'].count().sort_values(ascending=False).reset_index(name='Number_of_Pokemons')
    display(tmp_df_types.head())
    display(tmp_df_data)

    print(f'삭제 대상 컬럼 : {drop_col}')
    print(f'삭제 대상 데이터 : {drop_data}')

    print('='*20,'삭제 작업 이후 상태입니다.', '='*20)
    tmp_df_types = tmp_df_types[~tmp_df_types['Type'].isin(drop_data)]
    tmp_df_data1 = tmp_df_data[~tmp_df_data['Type'].isin(drop_data)]

    print(tmp_df_types.shape)
    display(tmp_df_types.head())
    display(tmp_df_data1)

    print('='*20,'시각화 결과입니다.', '='*20)
    fig , ax = plt.subplots(1, 2)
    sns.barplot(tmp_df_data, x='Type', y='Number_of_Pokemons', ax=ax[0])
    sns.barplot(tmp_df_data1, x='Type', y='Number_of_Pokemons', ax=ax[1])
    plt.tight_layout()
    plt.show()


prep_function(df=tmp_df,
              drop_col = 'Type',
              drop_data = ['GRASS', 'POISON'])
# Out:
# ==================== 삭제 작업 이전 상태입니다. ====================
# (178, 2)
#             Name   Type
# 0      Bulbasaur  GRASS
# 1        Ivysaur  GRASS
# 2       Venusaur  GRASS
# 3  Mega Venusaur  GRASS
# 4     Charmander   FIRE
#      Type  Number_of_Pokemons
# 0   GRASS                  69
# 1    FIRE                  50
# 2  POISON                  28
# 3  DRAGON                  27
# 4  FLYING                   4
# 삭제 대상 컬럼 : Type
# 삭제 대상 데이터 : ['GRASS', 'POISON']
# ==================== 삭제 작업 이후 상태입니다. ====================
# (81, 2)
#                Name  Type
# 4        Charmander  FIRE
# 5        Charmeleon  FIRE
# 6         Charizard  FIRE
# 7  Mega Charizard X  FIRE
# 8  Mega Charizard Y  FIRE
#      Type  Number_of_Pokemons
# 1    FIRE                  50
# 3  DRAGON                  27
# 4  FLYING                   4
# ==================== 시각화 결과입니다. ====================

# %% [markdown]
# <img src="./참고이미지/Q4/Q4_result3.png">

# %% [markdown]
# ## Q5. 데이터베이스 테이블에서 데이터 삭제

# %% [markdown]
# - 작업 개요
#     - 데이터 삭제 전, 원본 전체 데이터를 불러와 현재 상태를 확인합니다.
#     - 이후 **Python 환경에서 MySQL**를 활용하여 지정된 조건에 따라 **데이터베이스 테이블에서 데이터를 삭제**합니다.
#
# - 유의사항
#     - 삭제 작업은 반드시 **SQL 문법**을 사용하여 Python 코드 내에서 실행되어야 합니다.
#     - 삭제된 결과가 올바르게 반영되었는지, 삭제 후 테이블 상태를 **재조회하여 확인**해야 합니다.

# %% [markdown]
# - 전체 데이터에 대한 정보를 확인합니다.

# %%
# Python과 MySQL을 연결하여 데이터 조회를 수행해주세요

conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='1234',
    database='pokemon'
)

query = """ 
SELECT *
FROM pokemon_prep
"""

tmp_sql = pd.read_sql(query, conn)

display(tmp_sql)
# Out:
#                  Name    Type  Total   HP  Attack  Defense  Special Attack  \
# 0          Charmander    FIRE    309   39      52       43              60
# 1          Charmeleon    FIRE    405   58      64       58              80
# 2           Charizard    FIRE    534   78      84       78             109
# 3    Mega Charizard X    FIRE    634   78     130      111             130
# 4    Mega Charizard Y    FIRE    634   78     104       78             159
# ..                ...     ...    ...  ...     ...      ...             ...
# 768        Chesnaught   GRASS    530   88     107      122              74
# 769            Skiddo   GRASS    350   66      65       48              62
# 770            Gogoat   GRASS    531  123     100       62              97
# 771            Skrelp  POISON    320   50      60       60              60
# 772          Dragalge  POISON    494   65      75       90              97
#
#      Special Defense  Speed
# 0                 50     65
# 1                 65     80
# 2                 85    100
# 3                 85    100
# 4                115    100
# ..               ...    ...
# 768               75     64
# 769               57     52
# 770               81     68
# 771               60     30
# 772              123     44
#
# [773 rows x 9 columns]

# %% [markdown]
# <img src="./참고이미지/Q5/Q5_result1.png" width="90%">`

# %% [markdown]
# - 삭제 대상 데이터에 대한 정보를 확인합니다.
#     - 삭제 대상 : ('GRASS', 'POISON')

# %%
# 삭제 대상 데이터를 확인하기 위한 쿼리를 작성해주세요
# 삭제 대상 추출은 쿼리를 통해서 진행합니다.
# 전체 데이터를 추출하고, Python에서 전처리를 수행할 경우, 오답으로 처리됩니다.

query = """
SELECT *
FROM pokemon_prep
WHERE Type IN ('GRASS','POISON')
;
"""

tmp_sql = pd.read_sql(query, conn)

display(tmp_sql)
# Out:
#              Name    Type  Total   HP  Attack  Defense  Special Attack  \
# 0       Bulbasaur   GRASS    318   45      49       49              65
# 1         Ivysaur   GRASS    405   60      62       63              80
# 2        Venusaur   GRASS    525   80      82       83             100
# 3   Mega Venusaur   GRASS    625   80     100      123             122
# 4           Ekans  POISON    288   35      60       44              40
# ..            ...     ...    ...  ...     ...      ...             ...
# 92     Chesnaught   GRASS    530   88     107      122              74
# 93         Skiddo   GRASS    350   66      65       48              62
# 94         Gogoat   GRASS    531  123     100       62              97
# 95         Skrelp  POISON    320   50      60       60              60
# 96       Dragalge  POISON    494   65      75       90              97
#
#     Special Defense  Speed
# 0                65     45
# 1                80     60
# 2               100     80
# 3               120     80
# 4                54     55
# ..              ...    ...
# 92               75     64
# 93               57     52
# 94               81     68
# 95               60     30
# 96              123     44
#
# [97 rows x 9 columns]

# %% [markdown]
# <img src="./참고이미지/Q5/Q5_result2.png" width="90%">

# %% [markdown]
# - 데이터베이스 테이블에 대해 데이터 삭제 작업을 진행합니다.
#     - 데이터베이스 테이블에서 실제로 데이터가 삭제되어야 합니다.
#     - 삭제를 진행하고 다시 데이터베이스에서 테이블 정보를 불러와서 삭제가 올바르게 진행되었는지 확인합니다.

# %%
# Python과 MySQL을 연결 및 데이터 삭제 코드를 작성해주세요.
cursor = conn.cursor()

query1 = "DELETE FROM pokemon_prep WHERE Type IN ('GRASS', 'POISON')"
cursor.execute(query1)
conn.commit()

query2 = """
SELECT *
FROM pokemon_prep
"""
tmp_sql = pd.read_sql(query2, conn)

display(tmp_sql)
# Out:
#                  Name    Type  Total   HP  Attack  Defense  Special Attack  \
# 0          Charmander    FIRE    309   39      52       43              60
# 1          Charmeleon    FIRE    405   58      64       58              80
# 2           Charizard    FIRE    534   78      84       78             109
# 3    Mega Charizard X    FIRE    634   78     130      111             130
# 4    Mega Charizard Y    FIRE    634   78     104       78             159
# ..                ...     ...    ...  ...     ...      ...             ...
# 671            Noibat  FLYING    245   40      30       35              45
# 672           Noivern  FLYING    535   85      70       80              97
# 673           Xerneas   FAIRY    680  126     131       95             131
# 674           Yveltal    DARK    680  126     131       95             131
# 675           Zygarde  DRAGON    600  108     100      121              81
#
#      Special Defense  Speed
# 0                 50     65
# 1                 65     80
# 2                 85    100
# 3                 85    100
# 4                115    100
# ..               ...    ...
# 671               40     55
# 672               80    123
# 673               98     99
# 674               98     99
# 675               95     95
#
# [676 rows x 9 columns]

# %% [markdown]
# <img src="./참고이미지/Q5/Q5_result3.png" width="90%">

# %% [markdown]
# ## Q6. 테이블에 삭제된 데이터 재삽입

# %% [markdown]
# - 작업 개요
#     - 이전에 삭제한 데이터를 다시 **데이터베이스 테이블에 삽입**합니다.
#     - 삽입이 완료된 후에는 해당 테이블을 다시 불러와 **정상적으로 삽입되었는지 확인**합니다.
#
# - 세부 작업 지침
#     - 제공된 **CSV 파일**에서 필요한 데이터만 선택하여 사용합니다.
#     - **Python 환경에서 MySQL을 활용하여** 데이터베이스 테이블에 데이터를 삽입합니다.
#     - **데이터 정렬 순서는 정답에 영향을 미치지 않습니다.**

# %%
# 데이터 읽기 및 확인용 코드셀입니다.

import pandas as pd
origin_df = pd.read_csv('./data/pokemon_prep.csv')
display(origin_df.shape)
display(origin_df)
display(origin_df.columns)
# Out:
# (773, 9)
#               Name    Type  Total   HP  Attack  Defense  Special Attack  \
# 0        Bulbasaur   GRASS    318   45      49       49              65
# 1          Ivysaur   GRASS    405   60      62       63              80
# 2         Venusaur   GRASS    525   80      82       83             100
# 3    Mega Venusaur   GRASS    625   80     100      123             122
# 4       Charmander    FIRE    309   39      52       43              60
# ..             ...     ...    ...  ...     ...      ...             ...
# 768         Noibat  FLYING    245   40      30       35              45
# 769        Noivern  FLYING    535   85      70       80              97
# 770        Xerneas   FAIRY    680  126     131       95             131
# 771        Yveltal    DARK    680  126     131       95             131
# 772        Zygarde  DRAGON    600  108     100      121              81
#
#      Special Defense  Speed
# 0                 65     45
# 1                 80     60
# 2                100     80
# 3                120     80
# 4                 50     65
# ..               ...    ...
# 768               40     55
# 769               80    123
# 770               98     99
# 771               98     99
# 772               95     95
#
# [773 rows x 9 columns]
# Index(['Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'Special Attack',
#        'Special Defense', 'Speed'],
#       dtype='object')

# %% [markdown]
# <img src="./참고이미지/Q6/Q6_result1.png" width="90%">

# %% [markdown]
# - Pandas를 통해 csv에서 'GRASS', 'POISON' 데이터 정보를 확인합니다.

# %%
# 정보 조회를 위한 코드를 작성해주세요

data_drop = origin_df[(origin_df['Type'] == 'GRASS') | (origin_df['Type'] == 'POISON')]
display(data_drop)
# Out:
#               Name    Type  Total   HP  Attack  Defense  Special Attack  \
# 0        Bulbasaur   GRASS    318   45      49       49              65
# 1          Ivysaur   GRASS    405   60      62       63              80
# 2         Venusaur   GRASS    525   80      82       83             100
# 3    Mega Venusaur   GRASS    625   80     100      123             122
# 26           Ekans  POISON    288   35      60       44              40
# ..             ...     ...    ...  ...     ...      ...             ...
# 699     Chesnaught   GRASS    530   88     107      122              74
# 719         Skiddo   GRASS    350   66      65       48              62
# 720         Gogoat   GRASS    531  123     100       62              97
# 738         Skrelp  POISON    320   50      60       60              60
# 739       Dragalge  POISON    494   65      75       90              97
#
#      Special Defense  Speed
# 0                 65     45
# 1                 80     60
# 2                100     80
# 3                120     80
# 26                54     55
# ..               ...    ...
# 699               75     64
# 719               57     52
# 720               81     68
# 738               60     30
# 739              123     44
#
# [97 rows x 9 columns]

# %% [markdown]
# <img src="./참고이미지/Q6/Q6_result2.png" width="90%">

# %% [markdown]
# - 해당 데이터를 데이터베이스 테이블에 삽입합니다.

# %%
# 데이터 삽입을 위한 코드를 작성해주세요
# 출력 결과는 참고용입니다.

import pymysql

conn = pymysql.connect(
    host='localhost',
    user='root',
    password='1234',
    database='pokemon'
)
cursor = conn.cursor()

rows = data_drop.to_dict(orient='records')

for row in rows:
    print(row)
    sql = """INSERT INTO pokemon_prep (Name, Type, Total, HP, Attack, Defense, `Special Attack`, `Special Defense`, Speed)
             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"""
    cursor.execute(sql, tuple(row.values()))

conn.commit()
print("데이터 INSERT 완료")

cursor.close()
conn.close()
# Out:
# {'Name': 'Bulbasaur', 'Type': 'GRASS', 'Total': 318, 'HP': 45, 'Attack': 49, 'Defense': 49, 'Special Attack': 65, 'Special Defense': 65, 'Speed': 45}
# {'Name': 'Ivysaur', 'Type': 'GRASS', 'Total': 405, 'HP': 60, 'Attack': 62, 'Defense': 63, 'Special Attack': 80, 'Special Defense': 80, 'Speed': 60}
# {'Name': 'Venusaur', 'Type': 'GRASS', 'Total': 525, 'HP': 80, 'Attack': 82, 'Defense': 83, 'Special Attack': 100, 'Special Defense': 100, 'Speed': 80}
# {'Name': 'Mega Venusaur', 'Type': 'GRASS', 'Total': 625, 'HP': 80, 'Attack': 100, 'Defense': 123, 'Special Attack': 122, 'Special Defense': 120, 'Speed': 80}
# {'Name': 'Ekans', 'Type': 'POISON', 'Total': 288, 'HP': 35, 'Attack': 60, 'Defense': 44, 'Special Attack': 40, 'Special Defense': 54, 'Speed': 55}
# {'Name': 'Arbok', 'Type': 'POISON', 'Total': 438, 'HP': 60, 'Attack': 85, 'Defense': 69, 'Special Attack': 65, 'Special Defense': 79, 'Speed': 80}
# {'Name': 'Nidoran♀', 'Type': 'POISON', 'Total': 275, 'HP': 55, 'Attack': 47, 'Defense': 52, 'Special Attack': 40, 'Special Defense': 40, 'Speed': 41}
# {'Name': 'Nidorina', 'Type': 'POISON', 'Total': 365, 'HP': 70, 'Attack': 62, 'Defense': 67, 'Special Attack': 55, 'Special Defense': 55, 'Speed': 56}
# {'Name': 'Nidoqueen', 'Type': 'POISON', 'Total': 495, 'HP': 90, 'Attack': 82, 'Defense': 87, 'Special Attack': 75, 'Special Defense': 85, 'Speed': 76}
# {'Name': 'Nidoran♂', 'Type': 'POISON', 'Total': 273, 'HP': 46, 'Attack': 57, 'Defense': 40, 'Special Attack': 40, 'Special Defense': 40, 'Speed': 50}
# {'Name': 'Nidorino', 'Type': 'POISON', 'Total': 365, 'HP': 61, 'Attack': 72, 'Defense': 57, 'Special Attack': 55, 'Special Defense': 55, 'Speed': 65}
# {'Name': 'Nidoking', 'Type': 'POISON', 'Total': 495, 'HP': 81, 'Attack': 92, 'Defense': 77, 'Special Attack': 85, 'Special Defense': 75, 'Speed': 85}
# {'Name': 'Zubat', 'Type': 'POISON', 'Total': 245, 'HP': 40, 'Attack': 45, 'Defense': 35, 'Special Attack': 30, 'Special Defense': 40, 'Speed': 55}
# {'Name': 'Golbat', 'Type': 'POISON', 'Total': 455, 'HP': 75, 'Attack': 80, 'Defense': 70, 'Special Attack': 65, 'Special Defense': 75, 'Speed': 90}
# {'Name': 'Oddish', 'Type': 'GRASS', 'Total': 320, 'HP': 45, 'Attack': 50, 'Defense': 55, 'Special Attack': 75, 'Special Defense': 65, 'Speed': 30}
# {'Name': 'Gloom', 'Type': 'GRASS', 'Total': 395, 'HP': 60, 'Attack': 65, 'Defense': 70, 'Special Attack': 85, 'Special Defense': 75, 'Speed': 40}
# {'Name': 'Vileplume', 'Type': 'GRASS', 'Total': 480, 'HP': 75, 'Attack': 80, 'Defense': 85, 'Special Attack': 100, 'Special Defense': 90, 'Speed': 50}
# {'Name': 'Bellsprout', 'Type': 'GRASS', 'Total': 300, 'HP': 50, 'Attack': 75, 'Defense': 35, 'Special Attack': 70, 'Special Defense': 30, 'Speed': 40}
# {'Name': 'Weepinbell', 'Type': 'GRASS', 'Total': 390, 'HP': 65, 'Attack': 90, 'Defense': 50, 'Special Attack': 85, 'Special Defense': 45, 'Speed': 55}
# {'Name': 'Victreebel', 'Type': 'GRASS', 'Total': 480, 'HP': 80, 'Attack': 105, 'Defense': 65, 'Special Attack': 100, 'Special Defense': 60, 'Speed': 70}
# {'Name': 'Grimer', 'Type': 'POISON', 'Total': 325, 'HP': 80, 'Attack': 80, 'Defense': 50, 'Special Attack': 40, 'Special Defense': 50, 'Speed': 25}
# {'Name': 'Muk', 'Type': 'POISON', 'Total': 500, 'HP': 105, 'Attack': 105, 'Defense': 75, 'Special Attack': 65, 'Special Defense': 100, 'Speed': 50}
# {'Name': 'Exeggcute', 'Type': 'GRASS', 'Total': 325, 'HP': 60, 'Attack': 40, 'Defense': 80, 'Special Attack': 60, 'Special Defense': 45, 'Speed': 40}
# {'Name': 'Exeggutor', 'Type': 'GRASS', 'Total': 520, 'HP': 95, 'Attack': 95, 'Defense': 85, 'Special Attack': 125, 'Special Defense': 65, 'Speed': 55}
# {'Name': 'Koffing', 'Type': 'POISON', 'Total': 340, 'HP': 40, 'Attack': 65, 'Defense': 95, 'Special Attack': 60, 'Special Defense': 45, 'Speed': 35}
# {'Name': 'Weezing', 'Type': 'POISON', 'Total': 490, 'HP': 65, 'Attack': 90, 'Defense': 120, 'Special Attack': 85, 'Special Defense': 70, 'Speed': 60}
# {'Name': 'Tangela', 'Type': 'GRASS', 'Total': 435, 'HP': 65, 'Attack': 55, 'Defense': 115, 'Special Attack': 100, 'Special Defense': 40, 'Speed': 60}
# {'Name': 'Chikorita', 'Type': 'GRASS', 'Total': 318, 'HP': 45, 'Attack': 49, 'Defense': 65, 'Special Attack': 49, 'Special Defense': 65, 'Speed': 45}
# {'Name': 'Bayleef', 'Type': 'GRASS', 'Total': 405, 'HP': 60, 'Attack': 62, 'Defense': 80, 'Special Attack': 63, 'Special Defense': 80, 'Speed': 60}
# {'Name': 'Meganium', 'Type': 'GRASS', 'Total': 525, 'HP': 80, 'Attack': 82, 'Defense': 100, 'Special Attack': 83, 'Special Defense': 100, 'Speed': 80}
# {'Name': 'Crobat', 'Type': 'POISON', 'Total': 535, 'HP': 85, 'Attack': 90, 'Defense': 80, 'Special Attack': 70, 'Special Defense': 80, 'Speed': 130}
# {'Name': 'Bellossom', 'Type': 'GRASS', 'Total': 480, 'HP': 75, 'Attack': 80, 'Defense': 85, 'Special Attack': 90, 'Special Defense': 100, 'Speed': 50}
# {'Name': 'Hoppip', 'Type': 'GRASS', 'Total': 250, 'HP': 35, 'Attack': 35, 'Defense': 40, 'Special Attack': 35, 'Special Defense': 55, 'Speed': 50}
# {'Name': 'Skiploom', 'Type': 'GRASS', 'Total': 340, 'HP': 55, 'Attack': 45, 'Defense': 50, 'Special Attack': 45, 'Special Defense': 65, 'Speed': 80}
# {'Name': 'Jumpluff', 'Type': 'GRASS', 'Total': 450, 'HP': 75, 'Attack': 55, 'Defense': 70, 'Special Attack': 55, 'Special Defense': 85, 'Speed': 110}
# {'Name': 'Sunkern', 'Type': 'GRASS', 'Total': 180, 'HP': 30, 'Attack': 30, 'Defense': 30, 'Special Attack': 30, 'Special Defense': 30, 'Speed': 30}
# {'Name': 'Sunflora', 'Type': 'GRASS', 'Total': 425, 'HP': 75, 'Attack': 75, 'Defense': 55, 'Special Attack': 105, 'Special Defense': 85, 'Speed': 30}
# {'Name': 'Treecko', 'Type': 'GRASS', 'Total': 310, 'HP': 40, 'Attack': 45, 'Defense': 35, 'Special Attack': 65, 'Special Defense': 55, 'Speed': 70}
# {'Name': 'Grovyle', 'Type': 'GRASS', 'Total': 405, 'HP': 50, 'Attack': 65, 'Defense': 45, 'Special Attack': 85, 'Special Defense': 65, 'Speed': 95}
# {'Name': 'Sceptile', 'Type': 'GRASS', 'Total': 530, 'HP': 70, 'Attack': 85, 'Defense': 65, 'Special Attack': 105, 'Special Defense': 85, 'Speed': 120}
# {'Name': 'Seedot', 'Type': 'GRASS', 'Total': 220, 'HP': 40, 'Attack': 40, 'Defense': 50, 'Special Attack': 30, 'Special Defense': 30, 'Speed': 30}
# {'Name': 'Nuzleaf', 'Type': 'GRASS', 'Total': 340, 'HP': 70, 'Attack': 70, 'Defense': 40, 'Special Attack': 60, 'Special Defense': 40, 'Speed': 60}
# {'Name': 'Shiftry', 'Type': 'GRASS', 'Total': 480, 'HP': 90, 'Attack': 100, 'Defense': 60, 'Special Attack': 90, 'Special Defense': 60, 'Speed': 80}
# {'Name': 'Shroomish', 'Type': 'GRASS', 'Total': 295, 'HP': 60, 'Attack': 40, 'Defense': 60, 'Special Attack': 40, 'Special Defense': 60, 'Speed': 35}
# {'Name': 'Breloom', 'Type': 'GRASS', 'Total': 460, 'HP': 60, 'Attack': 130, 'Defense': 80, 'Special Attack': 60, 'Special Defense': 60, 'Speed': 70}
# {'Name': 'Roselia', 'Type': 'GRASS', 'Total': 400, 'HP': 50, 'Attack': 60, 'Defense': 45, 'Special Attack': 100, 'Special Defense': 80, 'Speed': 65}
# {'Name': 'Gulpin', 'Type': 'POISON', 'Total': 302, 'HP': 70, 'Attack': 43, 'Defense': 53, 'Special Attack': 43, 'Special Defense': 53, 'Speed': 40}
# {'Name': 'Swalot', 'Type': 'POISON', 'Total': 467, 'HP': 100, 'Attack': 73, 'Defense': 83, 'Special Attack': 73, 'Special Defense': 83, 'Speed': 55}
# {'Name': 'Cacnea', 'Type': 'GRASS', 'Total': 335, 'HP': 50, 'Attack': 85, 'Defense': 40, 'Special Attack': 85, 'Special Defense': 40, 'Speed': 35}
# {'Name': 'Cacturne', 'Type': 'GRASS', 'Total': 475, 'HP': 70, 'Attack': 115, 'Defense': 60, 'Special Attack': 115, 'Special Defense': 60, 'Speed': 55}
# {'Name': 'Seviper', 'Type': 'POISON', 'Total': 458, 'HP': 73, 'Attack': 100, 'Defense': 60, 'Special Attack': 100, 'Special Defense': 60, 'Speed': 65}
# {'Name': 'Tropius', 'Type': 'GRASS', 'Total': 460, 'HP': 99, 'Attack': 68, 'Defense': 83, 'Special Attack': 72, 'Special Defense': 87, 'Speed': 51}
# {'Name': 'Turtwig', 'Type': 'GRASS', 'Total': 318, 'HP': 55, 'Attack': 68, 'Defense': 64, 'Special Attack': 45, 'Special Defense': 55, 'Speed': 31}
# {'Name': 'Grotle', 'Type': 'GRASS', 'Total': 405, 'HP': 75, 'Attack': 89, 'Defense': 85, 'Special Attack': 55, 'Special Defense': 65, 'Speed': 36}
# {'Name': 'Torterra', 'Type': 'GRASS', 'Total': 525, 'HP': 95, 'Attack': 109, 'Defense': 105, 'Special Attack': 75, 'Special Defense': 85, 'Speed': 56}
# {'Name': 'Budew', 'Type': 'GRASS', 'Total': 280, 'HP': 40, 'Attack': 30, 'Defense': 35, 'Special Attack': 50, 'Special Defense': 70, 'Speed': 55}
# {'Name': 'Roserade', 'Type': 'GRASS', 'Total': 505, 'HP': 60, 'Attack': 70, 'Defense': 55, 'Special Attack': 125, 'Special Defense': 105, 'Speed': 90}
# {'Name': 'Cherubi', 'Type': 'GRASS', 'Total': 275, 'HP': 45, 'Attack': 35, 'Defense': 45, 'Special Attack': 62, 'Special Defense': 53, 'Speed': 35}
# {'Name': 'Cherrim', 'Type': 'GRASS', 'Total': 450, 'HP': 70, 'Attack': 60, 'Defense': 70, 'Special Attack': 87, 'Special Defense': 78, 'Speed': 85}
# {'Name': 'Stunky', 'Type': 'POISON', 'Total': 329, 'HP': 63, 'Attack': 63, 'Defense': 47, 'Special Attack': 41, 'Special Defense': 41, 'Speed': 74}
# {'Name': 'Skuntank', 'Type': 'POISON', 'Total': 479, 'HP': 103, 'Attack': 93, 'Defense': 67, 'Special Attack': 71, 'Special Defense': 61, 'Speed': 84}
# {'Name': 'Skorupi', 'Type': 'POISON', 'Total': 330, 'HP': 40, 'Attack': 50, 'Defense': 90, 'Special Attack': 30, 'Special Defense': 55, 'Speed': 65}
# {'Name': 'Drapion', 'Type': 'POISON', 'Total': 500, 'HP': 70, 'Attack': 90, 'Defense': 110, 'Special Attack': 60, 'Special Defense': 75, 'Speed': 95}
# {'Name': 'Croagunk', 'Type': 'POISON', 'Total': 300, 'HP': 48, 'Attack': 61, 'Defense': 40, 'Special Attack': 61, 'Special Defense': 40, 'Speed': 50}
# {'Name': 'Toxicroak', 'Type': 'POISON', 'Total': 490, 'HP': 83, 'Attack': 106, 'Defense': 65, 'Special Attack': 86, 'Special Defense': 65, 'Speed': 85}
# {'Name': 'Carnivine', 'Type': 'GRASS', 'Total': 454, 'HP': 74, 'Attack': 100, 'Defense': 72, 'Special Attack': 90, 'Special Defense': 72, 'Speed': 46}
# {'Name': 'Snover', 'Type': 'GRASS', 'Total': 334, 'HP': 60, 'Attack': 62, 'Defense': 50, 'Special Attack': 62, 'Special Defense': 60, 'Speed': 40}
# {'Name': 'Abomasnow', 'Type': 'GRASS', 'Total': 494, 'HP': 90, 'Attack': 92, 'Defense': 75, 'Special Attack': 92, 'Special Defense': 85, 'Speed': 60}
# {'Name': 'Mega Abomasnow', 'Type': 'GRASS', 'Total': 594, 'HP': 90, 'Attack': 132, 'Defense': 105, 'Special Attack': 132, 'Special Defense': 105, 'Speed': 30}
# {'Name': 'Tangrowth', 'Type': 'GRASS', 'Total': 535, 'HP': 100, 'Attack': 100, 'Defense': 125, 'Special Attack': 110, 'Special Defense': 50, 'Speed': 50}
# {'Name': 'Leafeon', 'Type': 'GRASS', 'Total': 525, 'HP': 65, 'Attack': 110, 'Defense': 130, 'Special Attack': 60, 'Special Defense': 65, 'Speed': 95}
# {'Name': 'Shaymin- Land Forme', 'Type': 'GRASS', 'Total': 600, 'HP': 100, 'Attack': 100, 'Defense': 100, 'Special Attack': 100, 'Special Defense': 100, 'Speed': 100}
# {'Name': 'Shaymin- Sky Forme', 'Type': 'GRASS', 'Total': 600, 'HP': 100, 'Attack': 103, 'Defense': 75, 'Special Attack': 120, 'Special Defense': 75, 'Speed': 127}
# {'Name': 'Snivy', 'Type': 'GRASS', 'Total': 308, 'HP': 45, 'Attack': 45, 'Defense': 55, 'Special Attack': 45, 'Special Defense': 55, 'Speed': 63}
# {'Name': 'Servine', 'Type': 'GRASS', 'Total': 413, 'HP': 60, 'Attack': 60, 'Defense': 75, 'Special Attack': 60, 'Special Defense': 75, 'Speed': 83}
# {'Name': 'Serperior', 'Type': 'GRASS', 'Total': 528, 'HP': 75, 'Attack': 75, 'Defense': 95, 'Special Attack': 75, 'Special Defense': 95, 'Speed': 113}
# {'Name': 'Pansage', 'Type': 'GRASS', 'Total': 316, 'HP': 50, 'Attack': 53, 'Defense': 48, 'Special Attack': 53, 'Special Defense': 48, 'Speed': 64}
# {'Name': 'Simisage', 'Type': 'GRASS', 'Total': 498, 'HP': 75, 'Attack': 98, 'Defense': 63, 'Special Attack': 98, 'Special Defense': 63, 'Speed': 101}
# {'Name': 'Cottonee', 'Type': 'GRASS', 'Total': 280, 'HP': 40, 'Attack': 27, 'Defense': 60, 'Special Attack': 37, 'Special Defense': 50, 'Speed': 66}
# {'Name': 'Whimsicott', 'Type': 'GRASS', 'Total': 480, 'HP': 60, 'Attack': 67, 'Defense': 85, 'Special Attack': 77, 'Special Defense': 75, 'Speed': 116}
# {'Name': 'Petilil', 'Type': 'GRASS', 'Total': 280, 'HP': 45, 'Attack': 35, 'Defense': 50, 'Special Attack': 70, 'Special Defense': 50, 'Speed': 30}
# {'Name': 'Lilligant', 'Type': 'GRASS', 'Total': 480, 'HP': 70, 'Attack': 60, 'Defense': 75, 'Special Attack': 110, 'Special Defense': 75, 'Speed': 90}
# {'Name': 'Maractus', 'Type': 'GRASS', 'Total': 461, 'HP': 75, 'Attack': 86, 'Defense': 67, 'Special Attack': 106, 'Special Defense': 67, 'Speed': 60}
# {'Name': 'Trubbish', 'Type': 'POISON', 'Total': 329, 'HP': 50, 'Attack': 50, 'Defense': 62, 'Special Attack': 40, 'Special Defense': 62, 'Speed': 65}
# {'Name': 'Garbodor', 'Type': 'POISON', 'Total': 474, 'HP': 80, 'Attack': 95, 'Defense': 82, 'Special Attack': 60, 'Special Defense': 82, 'Speed': 75}
# {'Name': 'Foongus', 'Type': 'GRASS', 'Total': 294, 'HP': 69, 'Attack': 55, 'Defense': 45, 'Special Attack': 55, 'Special Defense': 55, 'Speed': 15}
# {'Name': 'Amoonguss', 'Type': 'GRASS', 'Total': 464, 'HP': 114, 'Attack': 85, 'Defense': 70, 'Special Attack': 85, 'Special Defense': 80, 'Speed': 30}
# {'Name': 'Ferroseed', 'Type': 'GRASS', 'Total': 305, 'HP': 44, 'Attack': 50, 'Defense': 91, 'Special Attack': 24, 'Special Defense': 86, 'Speed': 10}
# {'Name': 'Ferrothorn', 'Type': 'GRASS', 'Total': 489, 'HP': 74, 'Attack': 94, 'Defense': 131, 'Special Attack': 54, 'Special Defense': 116, 'Speed': 20}
# {'Name': 'Virizion', 'Type': 'GRASS', 'Total': 580, 'HP': 91, 'Attack': 90, 'Defense': 72, 'Special Attack': 90, 'Special Defense': 129, 'Speed': 108}
# {'Name': 'Chespin', 'Type': 'GRASS', 'Total': 313, 'HP': 56, 'Attack': 61, 'Defense': 65, 'Special Attack': 48, 'Special Defense': 45, 'Speed': 38}
# {'Name': 'Quilladin', 'Type': 'GRASS', 'Total': 405, 'HP': 61, 'Attack': 78, 'Defense': 95, 'Special Attack': 56, 'Special Defense': 58, 'Speed': 57}
# {'Name': 'Chesnaught', 'Type': 'GRASS', 'Total': 530, 'HP': 88, 'Attack': 107, 'Defense': 122, 'Special Attack': 74, 'Special Defense': 75, 'Speed': 64}
# {'Name': 'Skiddo', 'Type': 'GRASS', 'Total': 350, 'HP': 66, 'Attack': 65, 'Defense': 48, 'Special Attack': 62, 'Special Defense': 57, 'Speed': 52}
# {'Name': 'Gogoat', 'Type': 'GRASS', 'Total': 531, 'HP': 123, 'Attack': 100, 'Defense': 62, 'Special Attack': 97, 'Special Defense': 81, 'Speed': 68}
# {'Name': 'Skrelp', 'Type': 'POISON', 'Total': 320, 'HP': 50, 'Attack': 60, 'Defense': 60, 'Special Attack': 60, 'Special Defense': 60, 'Speed': 30}
# {'Name': 'Dragalge', 'Type': 'POISON', 'Total': 494, 'HP': 65, 'Attack': 75, 'Defense': 90, 'Special Attack': 97, 'Special Defense': 123, 'Speed': 44}
# 데이터 INSERT 완료

# %% [markdown]
# <img src="./참고이미지/Q6/Q6_result3.png">

# %%
# Python과 MySQL을 연결하여 데이터베이스 테이블의 데이터를 확인해주세요

conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='1234',
    database='pokemon'
)

query="""
SELECT *
FROM pokemon_prep
"""

result = pd.read_sql(query, conn)

display(result)
# Out:
#                  Name    Type  Total   HP  Attack  Defense  Special Attack  \
# 0          Charmander    FIRE    309   39      52       43              60
# 1          Charmeleon    FIRE    405   58      64       58              80
# 2           Charizard    FIRE    534   78      84       78             109
# 3    Mega Charizard X    FIRE    634   78     130      111             130
# 4    Mega Charizard Y    FIRE    634   78     104       78             159
# ..                ...     ...    ...  ...     ...      ...             ...
# 768        Chesnaught   GRASS    530   88     107      122              74
# 769            Skiddo   GRASS    350   66      65       48              62
# 770            Gogoat   GRASS    531  123     100       62              97
# 771            Skrelp  POISON    320   50      60       60              60
# 772          Dragalge  POISON    494   65      75       90              97
#
#      Special Defense  Speed
# 0                 50     65
# 1                 65     80
# 2                 85    100
# 3                 85    100
# 4                115    100
# ..               ...    ...
# 768               75     64
# 769               57     52
# 770               81     68
# 771               60     30
# 772              123     44
#
# [773 rows x 9 columns]

# %% [markdown]
# <img src="./참고이미지/Q6/Q6_result4.png" width="90%">

# %% [markdown]
# ## **🔎 [주관식 과제 수행 시 유의사항]**
#
# > **✅ 1. 정확한 출력값과 요구사항 이행 필수**
#
# 주관식 채점은 다음 기준에 따라 평가됩니다.
#
# 1)출력 결과의 정확성
# - 제공된 예시 결과와 동일한 출력이 나와야 합니다.
# - 단, 실시간 데이터나 인공지능 학습 등으로 출력값에 변동성이 존재할 수 있는 문제는 예외로 처리합니다.
#
# 2)문제 요구사항의 충실한 반영
# - 조건, 컬럼명, 출력 형식 등 모든 요구사항을 빠짐없이 반영해야 합니다.
# - 사소한 조건도 놓치지 않도록 세심하게 코드를 작성해 주세요.
#
#
# > **✅ 2. 완성된 코드 제출 필수**
#
# 가. 제출한 코드 셀은 채점 시 직접 실행하여 결과를 확인할 수 있습니다.
#
# - 재실행 시에도 동일한 결과가 나와야 정답으로 인정됩니다.
#
# 나. 버전 차이에 따른 미세한 수치 차이는 감안하나, 결과 형태나 구조가 다르면 감점 또는 오답 처리될 수 있습니다.
#
# 다. 시각화 문제에서 색상 지정이 없다면, 기본(default) 색상 사용을 전제로 합니다.
# - 환경에 따라 색상이 다르게 출력되더라도 불이익은 없습니다.
#
# > **✅ 3. 사용자 선언 함수/클래스 문제 주의사항**
#
# 사용자 정의 함수, 클래스, 메서드와 관련된 문제에서는 추가적인 코드 없이도 함수만으로 정답 결과가 도출되어야 합니다.
# - ❌ 함수 외부에서 plt.title, print, info() 등을 추가하여 결과를 보완하면 오답 처리됩니다.
#
# > **✅ 4. 함수/클래스 선언 시 일관된 결과 유지**
#
# 가. 함수, 클래스, 메서드는 반복 실행 시에도 항상 동일한 결과를 반환해야 합니다.
# 나. 채점 중 재실행 결과가 다르면 오답으로 처리됩니다.
#
# > **📌 [안내 정리]**
#
# 가. 문제의 모든 조건을 꼼꼼히 확인하고 반영해 주세요.
# 나. 과제는 실무와 유사한 기준으로 평가되며, 요구 조건을 충족하지 않을 경우 0점 처리될 수 있습니다.
